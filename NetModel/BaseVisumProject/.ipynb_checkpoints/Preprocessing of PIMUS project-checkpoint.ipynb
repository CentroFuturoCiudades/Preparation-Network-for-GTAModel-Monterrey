# %%
import geopandas

# %%
gpd = geopandas.read_file('Shapefiles/SHP_MTY/Red_vial.shp')

# %%
gpd
# Out:
#             ID    LENGTH  DIR  VEL_TPU_AB  VEL_TPU_BA  VEL_TPR_AB  VEL_TPR_BA  \
# 0            1  0.502877    0   27.669654         NaN        22.0         NaN
# 1            2  0.046908    0         NaN         NaN         NaN         NaN
# 2            3  0.262938    0         NaN   28.494364         NaN   18.666667
# 3            4  0.160103    0         NaN         NaN         NaN         NaN
# 4            5  0.042009    0         NaN         NaN         NaN         NaN
# ...        ...       ...  ...         ...         ...         ...         ...
# 186678  186679  0.012152    0         NaN         NaN        60.0         NaN
# 186679  186680  0.151880    0         NaN         NaN        50.0         NaN
# 186680  186681  0.055316    0         NaN         NaN        60.0   60.000000
# 186681  186682  0.057682    0         NaN         NaN        80.0   80.000000
# 186682  186683  0.113951    0         NaN         NaN        45.0         NaN
#
# ...
